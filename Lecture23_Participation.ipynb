# %% [markdown]
# Jonathon Vasilak Lecture 23 Participation

# %% [markdown]
# Problem 1

# %%
print('EG 10112 Assignment')
print('My name is Jonathon Vasilak')
print('I live in Knott Hall')
print('I plan to major in Computer Science')
# Out:
# EG 10112 Assignment
# My name is Jonathon Vasilak
# I live in Knott Hall
# I plan to major in Computer Science

# %% [markdown]
# Problem 2

# %%
x = 3
a = 8
b = 5
c = 12
y = a*(x**2)+b*x+c
print('The value of y is:')
print(y)
# Out:
# The value of y is:
# 99
